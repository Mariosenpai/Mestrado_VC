# %%
from src.main.model.textToSpeech.glowtts.inference import inferance_for_mel, inference_for_audio
from src.common.utils.visualizar import vizualizar_spectrogram
import IPython.display as ipd

# vizualizar_spectrogram(inferance_for_mel("Hello")[0])
audio, rate = inference_for_audio("Ola me chamo mario")
ipd.Audio(audio, rate=rate)
# Out:
# INFO:root:Loaded checkpoint 'C:\Users\USER\Documents\Mestrado\codigo\Mestrado_VC\src\main\model\textToSpeech\glowtts\weight\pretrained.pth' (iteration 0)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
