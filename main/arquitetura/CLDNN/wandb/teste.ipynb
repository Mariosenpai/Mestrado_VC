# %%
import numpy as np


class Csv_person():
    
    def __init__(self, client_id, path, sentence):
        self.client_id = client_id
        self.path = path
        self.setence = sentence

# %%
import pandas as pd

c = pd.read_csv(r'C:\Users\USER\Documents\Mestrado\codigo\Mestrado_VC\dataset\cv-corpus-mozilla-pt\pt\clip_durations.tsv', sep="\t")

# %%
t = 0
for _, i in c.iterrows():
    t+=i["duration[ms]"]
tm = t//c["duration[ms]"].__len__()
print(tm)
# Out:
# 4149

# %%
tm/1000
# Out:
# 4.149

# %%
lista = []
for _, i in c.iterrows():
    lista.append(Csv_person(i['client_id'], i['path'], i['sentence']))
    
lista.__len__()
# Out:
# 22302

# %%
c
# Out:
#                                               client_id  \
# 0     0013d14ec509d70922ca37445002304318751c13a7dbfb...
# 1     00ad3196dc7befd478600c0e24925480a237d7a83bd1ee...
# 2     01527239012eedfa338f8438c4c19c20214ab2d8117d90...
# 3     023a5e6a4ca85bad19139255b57274785ae3faae96a789...
# 4     0441155e81e79bb83afa99c4166db77c98631c4f25d998...
# ...                                                 ...
# 9574  90397ec7fde72c9e05667d38e05cd5dd5fc936e1fac81f...
# 9575  90397ec7fde72c9e05667d38e05cd5dd5fc936e1fac81f...
# 9576  beb66858ae6b39e150af8adbaa38af7a8aed6a0e9095f3...
# 9577  beb66858ae6b39e150af8adbaa38af7a8aed6a0e9095f3...
# 9578  0bbee1fcb607b44437645430d71e8a90becd2c0e4c87c1...
#
#                               path  \
# 0     common_voice_pt_36821417.mp3
# 1     common_voice_pt_23825479.mp3
# 2     common_voice_pt_35032765.mp3
# 3     common_voice_pt_37406298.mp3
# 4     common_voice_pt_36470085.mp3
# ...                            ...
# 9574  common_voice_pt_21917226.mp3
# ...

# %%
c.__len__()
# Out:
# 22302

# %%
c.__len__()
# Out:
# 24724

# %%
c.__len__()
# Out:
# 9577

# %%
a['audio']
# Out:
# array([ 0.0000000e+00,  8.7679863e-14, -1.1699992e-13, ...,
#         4.2414809e-09,  4.7849555e-09,  5.1332272e-09], dtype=float32)

# %%
from IPython.lib.display import Audio
import numpy as np
a = np.load(R"C:\Users\USER\Documents\Mestrado\codigo\Mestrado_VC\dataset\cv-corpus-mozilla-pt\data\Teste\common_voice_pt_19281610.npy", allow_pickle=True).item()
Audio(data=a['audio'], rate=a['sample_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
